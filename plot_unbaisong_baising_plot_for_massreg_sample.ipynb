# %%
import numpy as np
import os, glob
import matplotlib.pyplot as plt
import mplhep as hep
plt.style.use([hep.style.ROOT, hep.style.firamath])
import pickle
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.colors as mcolors
channel_list = ["Tracks_pt", "Tracks_dZSig", "Tracks_d0Sig", "ECAL_energy",
"HBHE_energy", "Pix_1", "Pix_2", "Pix_3", "Pix_4", "Tib_1", "Tib_2",
"Tib_3", "Tib_4", "Tob_1", "Tob_2", "Tob_3", "Tob_4", "Tob_5",
"Tob_6", "Tid_1", "Tec_1", "Tec_2", "Tec_3"]


# Define the CMS color scheme
cms_colors = [
    (0.00, '#FFFFFF'),  # White
    (0.33, '#005EB8'),  # Blue
    (0.66, '#FFDD00'),  # Yellow
    (1.00, '#FF0000')   # red
]

# Create the CMS colormap
cms_cmap = LinearSegmentedColormap.from_list('CMS', cms_colors)
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-04cgz5oh because the default path (/uscms/home/bbbam/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# Matplotlib is building the font cache; this may take a moment.

# %%
file = "../conversion_plot_scripts/plots_from_mass_mN1p2To1p2_Gev_unbiased_unphysical_pq_to_pq/0009/dataset_data_for_unphysical_plots_subset_0009.pkl"
infile = open(f"{file}", "rb")
data = pickle.load(infile)
infile.close()
data.keys()

pt_original0=data["pt_original"]
m_original0=data["m_original"]
pt_unphy0_=data["pt_unphy"]
m_unphy0_=data["m_unphy"]

mass_bins_un =np.arange(-1.6, 1.7, .4)
pt_bins = np.arange(30,200,5)
fig, ax = plt.subplots(figsize=(20,15))
norm = mcolors.TwoSlopeNorm(vmin=450, vmax = 550, vcenter=500)
plt.hist2d(np.squeeze(m_unphy0_), np.squeeze(pt_unphy0_), bins=[mass_bins_un, pt_bins],cmap=cms_cmap, norm=norm)
# plt.xticks(np.arange(0.8, 4.4, .4))
plt.yticks(np.arange(10,200,10))
plt.xlabel(r'$\mathrm{mass}$ [GeV]')
plt.ylabel(r'$\mathrm{pT}$ [GeV]')
plt.colorbar().set_label(label='Events/ (0.4,5) GeV')
plt.grid(color='r', linestyle='--', linewidth=.2)
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)

mass_bins =np.arange(0.8, 4.1, .4)
pt_bins = np.arange(30,200,5)
fig, ax = plt.subplots(figsize=(20,15))
norm = mcolors.TwoSlopeNorm(vmin=450, vmax = 550, vcenter=500)
plt.hist2d(np.squeeze(m_original0), np.squeeze(pt_original0), bins=[mass_bins, pt_bins],cmap=cms_cmap,norm=norm)
# plt.xticks(np.arange(0.8, 4.4, .4))
plt.yticks(np.arange(10,200,10))
plt.xlabel(r'$\mathrm{mass}$ [GeV]')
plt.ylabel(r'$\mathrm{pT}$ [GeV]')
plt.colorbar().set_label(label='Events/ (0.4,5) GeV')
plt.grid(color='r', linestyle='--', linewidth=.2)
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Preliminary'))

# %%
plt.hist(m_unphy0, bins=mass_bins_un)
# Out:
# (array([  0., 151., 171., 172., 192., 167., 147.,   0.]),
#  array([-1.6000000e+00, -1.2000000e+00, -8.0000000e-01, -4.0000000e-01,
#         -4.4408921e-16,  4.0000000e-01,  8.0000000e-01,  1.2000000e+00,
#          1.6000000e+00]),
#  <BarContainer object of 8 artists>)

# %%
data_file0 = "../conversion_plot_scripts/plots_from_root_to_pq_unbiased_m1p2To3p6_unphysical_v2/%s/data_for_unbaising_plots_dataset_aToTauTau_hadronic_dR0p4_m14To17p2_%s.pkl"%(dataset, dataset)
infile0 = open(f"{data_file0}", "rb")
data0 = pickle.load(infile0)
infile0.close()
data0.keys()
# Out:
# dict_keys(['jet_mass', 'pt_original', 'm_unbaised', 'pt_unbaised', 'm_original'])

# %%
dataset ="0001"

# %%
data_file0 = "../conversion_plot_scripts/plots_from_root_to_pq_unbiased_m1p2To3p6_unphysical_v2/%s/data_for_unbaising_plots_dataset_aToTauTau_hadronic_dR0p4_m14To17p2_%s.pkl"%(dataset, dataset)
infile0 = open(f"{data_file0}", "rb")
data0 = pickle.load(infile0)
infile0.close()
pt_original0=data0["pt_original"]
m_original0=data0["m_original"]
pt_unphy0=data0["pt_unbaised"]
m_unphy0=data0["m_unbaised"]






mass_bins =np.arange(0.8, 4.4, .4)
pt_bins = np.arange(30,200,5)
fig, ax = plt.subplots(figsize=(20,15))
norm = mcolors.TwoSlopeNorm(vmin=450, vmax = 550, vcenter=500)
plt.hist2d(np.squeeze(m_unphy0), np.squeeze(pt_unphy0), bins=[mass_bins, pt_bins],cmap=cms_cmap, norm =norm)
plt.xticks(np.arange(0.8, 4.4, .4))
plt.yticks(np.arange(10,200,10))
plt.xlabel(r'$\mathrm{mass}$ [GeV]')
plt.ylabel(r'$\mathrm{pT}$ [GeV]')
plt.colorbar().set_label(label='Events/ (0.4,5) GeV')
plt.grid(color='r', linestyle='--', linewidth=.2)
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)

mass_bins =np.arange(0.8, 4.4, .4)
pt_bins = np.arange(30,200,5)
fig, ax = plt.subplots(figsize=(20,15))
# norm = mcolors.TwoSlopeNorm(vmin=450, vmax = 550, vcenter=500)
plt.hist2d(np.squeeze(m_original0), np.squeeze(pt_original0), bins=[mass_bins, pt_bins],cmap=cms_cmap)
plt.xticks(np.arange(0.8, 4.4, .4))
plt.yticks(np.arange(10,200,10))
plt.xlabel(r'$\mathrm{mass}$ [GeV]')
plt.ylabel(r'$\mathrm{pT}$ [GeV]')
plt.colorbar().set_label(label='Events/ (0.4,5) GeV')
plt.grid(color='r', linestyle='--', linewidth=.2)
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Preliminary'))

# %%
ls ../conversion_plot_scripts/plots_from_pq_unbiased_m3p6To14p8_v2/IMG_aToTauTau_Hadronic_tauDR0p4_m3p6To14p8_dataset_2_unbaised_v2/0000
# Out:
# data_for_unbaising_plots_dataset_aToTauTau_hadronic_dR0p4_m14To17p2_0000.pkl
# mass_VS_pt_original.png
# mass_VS_pt_unbiased.png
# mass_distribution_original.png
# mass_distribution_unbiased.png
# pt_distribution_original.png
# pt_distribution_unbiased.png

# %%
data_file2 = "../conversion_plot_scripts/plots_from_pq_unbiased_m3p6To14p8_v2/IMG_aToTauTau_Hadronic_tauDR0p4_m3p6To14p8_dataset_2_unbaised_v2/%s/data_for_unbaising_plots_dataset_aToTauTau_hadronic_dR0p4_m14To17p2_%s.pkl"%(dataset, dataset)
infile2 = open(f"{data_file2}", "rb")
data2 = pickle.load(infile2)
infile2.close()
pt_original2=data2["pt_original"]
m_original2=data2["m_original"]
pt_unbaised2=data2["pt_unbaised"]
m_unbaised2=data2["m_unbaised"]

mass_bins =np.arange(3.2, 15.3, .4)
pt_bins = np.arange(30,200,5)
fig, ax = plt.subplots(figsize=(20,15))
norm = mcolors.TwoSlopeNorm(vmin=450, vmax = 550, vcenter=500)
plt.hist2d(np.squeeze(m_original2), np.squeeze(pt_original2), bins=[mass_bins, pt_bins],cmap=cms_cmap)
plt.xticks(np.arange(3.2, 15.3, .8))
plt.yticks(np.arange(10,200,10))
plt.xlabel(r'$\mathrm{mass}$ [GeV]')
plt.ylabel(r'$\mathrm{pT}$ [GeV]')
plt.colorbar().set_label(label='Events/ (0.4,5) GeV')
plt.grid(color='r', linestyle='--', linewidth=.2)
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)

mass_bins =np.arange(3.2, 15.3, .4)
pt_bins = np.arange(30,200,5)
fig, ax = plt.subplots(figsize=(20,15))
norm = mcolors.TwoSlopeNorm(vmin=450, vmax = 550, vcenter=500)
plt.hist2d(np.squeeze(m_unbaised2), np.squeeze(pt_unbaised2), bins=[mass_bins, pt_bins],cmap=cms_cmap, norm =norm)
plt.xticks(np.arange(3.2, 15.3, .8))
plt.yticks(np.arange(10,200,10))
plt.xlabel(r'$\mathrm{mass}$ [GeV]')
plt.ylabel(r'$\mathrm{pT}$ [GeV]')
plt.colorbar().set_label(label='Events/ (0.4,5) GeV')
plt.grid(color='r', linestyle='--', linewidth=.2)
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Preliminary'))

# %%
data_file3 = "../conversion_plot_scripts/plots_from_pq_unbiased_m14p8To17p2_v2/IMG_aToTauTau_Hadronic_tauDR0p4_m14To17p2_dataset_2_unbaised/%s/data_for_unbaising_plots_dataset_aToTauTau_hadronic_dR0p4_m14To17p2_%s.pkl"%(dataset, dataset)
infile3 = open(f"{data_file3}", "rb")
data3 = pickle.load(infile3)
infile3.close()
pt_original3=data3["pt_original"]
m_original3=data3["m_original"]
pt_unbaised3=data3["pt_unbaised"]
m_unbaised3=data3["m_unbaised"]
mass_bins =np.arange(14.4 ,17.6, .4)
pt_bins = np.arange(30,200,5)
fig, ax = plt.subplots(figsize=(20,15))
norm = mcolors.TwoSlopeNorm(vmin=450, vmax = 600, vcenter=500)
plt.hist2d(np.squeeze(m_original3), np.squeeze(pt_original3), bins=[mass_bins, pt_bins],cmap=cms_cmap)
plt.xticks(np.arange(14.4 ,17.6, .4))
plt.yticks(np.arange(10,200,10))
plt.xlabel(r'$\mathrm{mass}$ [GeV]')
plt.ylabel(r'$\mathrm{pT}$ [GeV]')
plt.colorbar().set_label(label='Events/ (0.4,5) GeV')
plt.grid(color='r', linestyle='--', linewidth=.2)
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)

mass_bins =np.arange(14.4 ,17.6, .4)
pt_bins = np.arange(30,200,5)
fig, ax = plt.subplots(figsize=(20,15))
norm = mcolors.TwoSlopeNorm(vmin=350, vmax = 600, vcenter=425)
plt.hist2d(np.squeeze(m_unbaised3), np.squeeze(pt_unbaised3), bins=[mass_bins, pt_bins],cmap=cms_cmap, norm =norm)
plt.xticks(np.arange(14.4 ,17.6, .4))
plt.yticks(np.arange(10,200,10))
plt.xlabel(r'$\mathrm{mass}$ [GeV]')
plt.ylabel(r'$\mathrm{pT}$ [GeV]')
plt.colorbar().set_label(label='Events/ (0.4,5) GeV')
plt.grid(color='r', linestyle='--', linewidth=.2)
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Preliminary'))

# %%
mass_bins =np.arange(-1.6 ,17.7, .4)
pt_bins = np.arange(30,200,5)
fig, ax = plt.subplots(figsize=(25,15))
norm = mcolors.TwoSlopeNorm(vmin=200, vmax = 600, vcenter=400)
plt.hist2d(np.squeeze(m_unphy0_+m_unphy0+m_unbaised2+ m_unbaised3), np.squeeze(pt_unphy0_+pt_unphy0+pt_unbaised2+pt_unbaised3), bins=[mass_bins, pt_bins],cmap=cms_cmap, norm =norm)
plt.xticks(np.arange(-1.6 ,17.7, .8))
plt.yticks(np.arange(10,200,10))
plt.xlabel(r'$\mathrm{mass}$ [GeV]')
plt.ylabel(r'$\mathrm{pT}$ [GeV]')
plt.colorbar().set_label(label='Events/ (0.4,5) GeV')
plt.grid(color='r', linestyle='--', linewidth=.2)
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Preliminary'))

# %%
mass_bins =np.arange(0.8 ,17.7, .4)
pt_bins = np.arange(30,200,5)
fig, ax = plt.subplots(figsize=(25,15))
# norm = mcolors.TwoSlopeNorm(vmin=200, vmax = 600, vcenter=400)
plt.hist2d(np.squeeze(m_original0+m_original2+ m_original3), np.squeeze(pt_original0+pt_original2+pt_original3), bins=[mass_bins, pt_bins],cmap=cms_cmap)
plt.xticks(np.arange(.8 ,17.7, .8))
plt.yticks(np.arange(10,200,10))
plt.xlabel(r'$\mathrm{mass}$ [GeV]')
plt.ylabel(r'$\mathrm{pT}$ [GeV]')
plt.colorbar().set_label(label='Events/ (0.4,5) GeV')
plt.grid(color='r', linestyle='--', linewidth=.2)
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3 fig, ax = plt.subplots(figsize=(25,15))
#       4 # norm = mcolors.TwoSlopeNorm(vmin=200, vmax = 600, vcenter=400)
# ----> 5 plt.hist2d(np.squeeze(m_original0+m_original2+ m_original3), np.squeeze(pt_original0+pt_original2+pt_original3), bins=[mass_bins, pt_bins],cmap=cms_cmap)
#       6 plt.xticks(np.arange(.8 ,17.7, .8))
#       7 plt.yticks(np.arange(10,200,10))
#
# NameError: name 'm_original2' is not defined
