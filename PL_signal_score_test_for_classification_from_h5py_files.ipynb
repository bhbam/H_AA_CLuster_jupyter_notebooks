# %%
import h5py
import glob
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
from sklearn.metrics import auc, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, roc_curve
import seaborn as sns

# %%
files3p7 = glob.glob("/global/homes/b/bbbam/boosted_tau_classifier_13ch/Inference_Mass_3p7/INFERENCE_DATA/*")
files4 = glob.glob("/global/homes/b/bbbam/boosted_tau_classifier_13ch/Inference_Mass_4/INFERENCE_DATA/*")
files5 = glob.glob("/global/homes/b/bbbam/boosted_tau_classifier_13ch/Inference_Mass_5/INFERENCE_DATA/*")
files6 = glob.glob("/global/homes/b/bbbam/boosted_tau_classifier_13ch/Inference_Mass_6/INFERENCE_DATA/*")
files8 = glob.glob("/global/homes/b/bbbam/boosted_tau_classifier_13ch/Inference_Mass_8/INFERENCE_DATA/*")
files10 = glob.glob("/global/homes/b/bbbam/boosted_tau_classifier_13ch/Inference_Mass_10/INFERENCE_DATA/*")
files12 = glob.glob("/global/homes/b/bbbam/boosted_tau_classifier_13ch/Inference_Mass_12/INFERENCE_DATA/*")
files14 = glob.glob("/global/homes/b/bbbam/boosted_tau_classifier_13ch/Inference_Mass_14/INFERENCE_DATA/*")
# files2 = glob.glob("/home/bbbam/boosted_tau_classifier_13ch/INFERENCE_DATA/*/*")
# print(len(files1),len(files2))
# print(files1[-1],files2[-1])

# %%
with h5py.File(files3p7[0], 'r') as file3p7:
        y_pred3p7 = np.squeeze(file3p7['y_pred'][()])
        
        
with h5py.File(files4[0], 'r') as file4:
        y_pred4 = np.squeeze(file4['y_pred'][()])
        
with h5py.File(files5[0], 'r') as file5:
        y_pred5 = np.squeeze(file5['y_pred'][()])



with h5py.File(files6[0], 'r') as file6:
        y_pred6 = np.squeeze(file6['y_pred'][()])

with h5py.File(files8[0], 'r') as file8:
        y_pred8 = np.squeeze(file8['y_pred'][()])

with h5py.File(files10[0], 'r') as file10:
        y_pred10 = np.squeeze(file10['y_pred'][()])
        
        
        
with h5py.File(files12[0], 'r') as file12:
        y_pred12 = np.squeeze(file12['y_pred'][()])
       
        
        
with h5py.File(files14[0], 'r') as file14:
        y_pred14 = np.squeeze(file14['y_pred'][()])
       
        
fig, ax = plt.subplots()
plt.hist(y_pred3p7, bins = np.arange(0,1.1,0.05), density=True, color='black',label='Mass 3.7',alpha=0.1)
plt.hist(y_pred4, bins = np.arange(0,1.1,0.05), histtype='step', density=True, color='r',label='Mass 4',alpha=0.9)
plt.hist(y_pred5, bins = np.arange(0,1.1,0.05), histtype='step', density=True, color='g',label='Mass 5',alpha=0.9)
plt.hist(y_pred6, bins = np.arange(0,1.1,0.05), histtype='step', density=True, color='b', label='Mass 6', alpha=0.9)
# plt.hist(y_pred8, bins = np.arange(0,1.1,0.05), histtype='step', density=True, color='black',label='Mass 8',alpha=0.1)
# plt.hist(y_pred10, bins = np.arange(0,1.1,0.05),histtype='step', density=True, color='r',label='Mass 10',alpha=0.5)
# plt.hist(y_pred12, bins = np.arange(0,1.1,0.05),histtype='step', density=True, color='g',label='Mass 12',alpha=0.5)
# plt.hist(y_pred14, bins = np.arange(0,1.1,0.05),histtype='step', density=True, color='b',label='Mass 14',alpha=0.5)
plt.xlabel('Classifier score')
plt.ylabel('Event (density)')
plt.legend(loc='best')
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
plt.show()

# %%
fig, ax = plt.subplots()
plt.hist(y_pred8, bins = np.arange(0,1.1,0.05), density=True, color='black',label='Mass 8',alpha=0.1)
plt.hist(y_pred10, bins = np.arange(0,1.1,0.05),histtype='step', density=True, color='r',label='Mass 10',alpha=0.9)
plt.hist(y_pred12, bins = np.arange(0,1.1,0.05),histtype='step', density=True, color='g',label='Mass 12',alpha=0.9)
plt.hist(y_pred14, bins = np.arange(0,1.1,0.05),histtype='step', density=True, color='b',label='Mass 14',alpha=0.9)
plt.xlabel('Classifier score')
plt.ylabel('Event (density)')
plt.legend(loc='best')
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
plt.show()

# %%
filesa = glob.glob("/global/homes/b/bbbam/boosted_tau_classifier_13ch/Inference_Mass_AToTauTau_m3p6To14p8/INFERENCE_DATA/*")
with h5py.File(filesa[0], 'r') as filea:
        y_preda = np.squeeze(filea['y_pred'][()])
       
        
fig, ax = plt.subplots()
plt.hist(y_preda, bins = np.arange(0,1.1,0.05)-, density=True, color='grey',label='3.6 to 14.8',alpha=0.5)

plt.xlabel('Classifier score')
plt.ylabel('Event (density)')
plt.legend(loc='best')
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
plt.show()

# %%
# Example true and predicted values
with h5py.File(files1[0], 'r') as file1:
        fpr = np.squeeze(file1['fpr'][()])  
        tpr = np.squeeze(file1['tpr'][()])
        y_pred = np.squeeze(file1['y_pred'][()])
        y_true = np.squeeze(file1['y_truth'][()])
y_pred = np.squeeze(np.array([1 if true > 0.5 else 0 for true in y_pred]))


        
#Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print(f"Accuracy: {accuracy:.2%}")

# Calculate precision
precision = precision_score(y_true, y_pred)
print(f"Precision: {precision:.2%}")

# Calculate recall
recall = recall_score(y_true, y_pred)
print(f"Recall: {recall:.2%}")

# Calculate F1 score
f1 = f1_score(y_true, y_pred)
print(f"F1 Score: {f1:.2%}")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Plot confusion matrix as a heatmap
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])

plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Calculate ROC-AUC score

# Plot ROC curve
# fpr, tpr, _ = roc_curve(y_true, y_pred)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve: AUC={np.round(auc(fpr, tpr),3)}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve ')
plt.legend(loc="lower right")
plt.show()
# Out:
# Accuracy: 89.84%
# Precision: 92.17%
# Recall: 87.24%
# F1 Score: 89.64%
# Confusion Matrix:
# [[392855  31948]
#  [ 55026 376235]]

# %%
# Example true and predicted values
with h5py.File(files2[0], 'r') as file1:
        fpr = np.squeeze(file1['fpr'][()])  
        tpr = np.squeeze(file1['tpr'][()])
        y_pred = np.squeeze(file1['y_pred'][()])
        y_true = np.squeeze(file1['y_truth'][()])
y_pred = np.squeeze(np.array([1 if true > 0.5 else 0 for true in y_pred]))


        
#Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print(f"Accuracy: {accuracy:.2%}")

# Calculate precision
precision = precision_score(y_true, y_pred)
print(f"Precision: {precision:.2%}")

# Calculate recall
recall = recall_score(y_true, y_pred)
print(f"Recall: {recall:.2%}")

# Calculate F1 score
f1 = f1_score(y_true, y_pred)
print(f"F1 Score: {f1:.2%}")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Plot confusion matrix as a heatmap
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])

plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Calculate ROC-AUC score

# Plot ROC curve
# fpr, tpr, _ = roc_curve(y_true, y_pred)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve: AUC={np.round(auc(fpr, tpr),3)}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve ')
plt.legend(loc="lower right")
plt.show()
# Out:
# Accuracy: 90.76%
# Precision: 89.77%
# Recall: 92.16%
# F1 Score: 90.95%
# Confusion Matrix:
# [[379346  45315]
#  [ 33820 397583]]

# %%
with h5py.File(files1[0], 'r') as file1:
        fpr = np.squeeze(file1['fpr'][()])  
        tpr = np.squeeze(file1['tpr'][()])
        y_pred = np.squeeze(file1['y_pred'][()])
        y_true = np.squeeze(file1['y_truth'][()])
plt.hist(y_pred)
# Out:
# (array([190799.,  29258.,  15372.,  10797.,   9611.,   9302.,  10091.,
#          13348.,  22600., 198774.]),
#  array([0.        , 0.09999639, 0.19999278, 0.29998916, 0.39998555,
#         0.49998194, 0.59997833, 0.69997472, 0.7999711 , 0.89996749,
#         0.99996388]),
#  <BarContainer object of 10 artists>)

# %%
len(y_true[y_true==0])
# Out:
# 424661
